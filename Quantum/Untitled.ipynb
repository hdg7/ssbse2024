# %%
# %pip install pylatexenc
# %pip install qiskit
# %pip install qiskit-aer

import qiskit
from qiskit_aer import AerSimulator

# Generate 3-qubit GHZ state

circ = qiskit.QuantumCircuit(3)
circ.h(0)
circ.cx(0, 1)
circ.cx(1, 2)
circ.measure_all()
# Out:
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=b1bfbd62d1579dd107f4ba5270f0925442d6210c19e776bd11e7b91b7f0ccdd3
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b1/7a/33/9fdd892f784ed4afda62b685ae3703adf4c91aa0f524c28f03
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit
#   Downloading qiskit-1.0.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting rustworkx>=0.14.0 (from qiskit)
#   Downloading rustworkx-0.14.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: numpy<2,>=1.17 in /opt/conda/lib/python3.11/site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.11/site-packages (from qiskit) (1.12.0)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.11/site-packages (from qiskit) (1.12)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from qiskit) (2.9.0)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.2.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit) (4.10.0)
# Collecting symengine>=0.11 (from qiskit)
#   Downloading symengine-0.11.0-cp311-cp311-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Collecting pbr!=2.1.0,>=2.0.0 (from stevedore>=3.0.0->qiskit)
#   Downloading pbr-6.0.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Downloading qiskit-1.0.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading rustworkx-0.14.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading stevedore-5.2.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 2.2 MB/s eta 0:00:00
# Downloading symengine-0.11.0-cp311-cp311-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (39.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 2.1 MB/s eta 0:00:00 0:00:01
# Installing collected packages: symengine, rustworkx, pbr, stevedore, qiskit
# Successfully installed pbr-6.0.0 qiskit-1.0.2 rustworkx-0.14.2 stevedore-5.2.0 symengine-0.11.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: qiskit>=0.45.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-aer) (1.0.2)
# Requirement already satisfied: numpy>=1.16.3 in /opt/conda/lib/python3.11/site-packages (from qiskit-aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-aer) (1.12.0)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.11/site-packages (from qiskit-aer) (5.9.8)
# Requirement already satisfied: rustworkx>=0.14.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit-aer) (0.14.2)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit-aer) (1.12)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit-aer) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit-aer) (2.9.0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit-aer) (5.2.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit-aer) (4.10.0)
# Requirement already satisfied: symengine>=0.11 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit-aer) (0.11.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit>=0.45.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit>=0.45.0->qiskit-aer) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.3->qiskit>=0.45.0->qiskit-aer) (1.3.0)
# Downloading qiskit_aer-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 2.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.13.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# The Qiskit circuit object supports composition.
# Here the meas has to be first and front=True (putting it before) 
# as compose must put a smaller circuit into a larger one.
meas = qiskit.QuantumCircuit(3, 3)
meas.barrier(range(3))
meas.measure(range(3), range(3))
qc = meas.compose(circ, range(3), front=True)

#drawing the circuit
qc.draw('mpl')

# %%
# Adding the transpiler to reduce the circuit to QASM instructions
# supported by the backend
from qiskit import transpile 

# Use AerSimulator
from qiskit_aer import AerSimulator

backend = AerSimulator()

# First we have to transpile the quantum circuit 
# to the low-level QASM instructions used by the 
# backend
qc_compiled = transpile(qc, backend)

# Execute the circuit on the qasm simulator.
# We've set the number of repeats of the circuit
# to be 1024, which is the default.
job_sim = backend.run(qc_compiled, shots=1024)

# Grab the results from the job.
result_sim = job_sim.result()

# %%
counts = result_sim.get_counts(qc_compiled)
print(counts)
# Out:
# {'000': 520, '111': 504}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)
